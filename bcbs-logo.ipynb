# %% [markdown]
# # Counting dice with Computer Vision
#
#
# ![](https://upload.wikimedia.org/wikipedia/commons/thumb/3/36/Two_red_dice_01.svg/671px-Two_red_dice_01.svg.png)

# %% [markdown]
# ## SageMaker Ground-Truth

# %% [markdown]
# You'll shortly step through the process of setting up a SageMaker ground-truth labelling job, but first we need to upload our images to Amazon S3.
#
# We have already loaded the images onto this SageMaker Notebook instance, and you can find them at `./data`.
#
# Using the Amazon SageMaker SDK we can upload these images to the default bucket. See `session.upload_data` below.

# %%
import sagemaker

session = sagemaker.session.Session()
default_s3_bucket = 's3://bcbs-logos'
print('default_s3_bucket: {}'.format(default_s3_bucket))
# Out:
# default_s3_bucket: s3://bcbs-logos

# %%
#training_images = session.upload_data('./data', key_prefix='vegas-dice-images')

# %% [markdown]
# You should now open the [AWS Management Console](https://console.aws.amazon.com/sagemaker/groundtruth?region=us-east-1#/labeling-jobs) and setup your SageMaker ground-truth labeling job.

# %%
#print("Bucket for ground-truth Labeling: {}/images/".format(training_images))
# Out:
# Bucket for ground-truth Labeling: s3://sagemaker-us-east-1-627967994532/vegas-dice-images/images/

# %% [markdown]
# ## Exploritory Data Analysis

# %% [markdown]
# In this section we are going to download and explore the data. This is a dataset that has been labeled in ground-truth and contains the bounding boxes for the dice present in the picture from the training dataset

# %% [markdown]
# It is recommended at the beginning of any ML project to get well acquainted with the format and type of data that you are working with, on a qualitative and quantitative level

# %%
# !pip install gluoncv --pre -q
# Out:
# You are using pip version 10.0.1, however version 19.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import glob
import json
import math
import os
import random
import time
import zipfile

import cv2
import gluoncv as gcv
import matplotlib.pyplot as plt
import mxnet as mx
import numpy as np

# %% [markdown]
# ### Visualize the images

# %%
import boto3
s3=boto3.client('s3')
list=s3.list_objects(Bucket='bcbs-logos')['Contents']
for key in list:
    s3.download_file('bcbs-logos', key['Key'], key['Key'])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-3917b7e6ae9f> in <module>()
#       3 list=s3.list_objects(Bucket='bcbs-logos')['Contents']
#       4 for key in list:
# ----> 5     s3.download_file('bcbs-logos', key['Key'], key['Key'])
#
# ~/anaconda3/envs/mxnet_p36/lib/python3.6/site-packages/boto3/s3/inject.py in download_file(self, Bucket, Key, Filename, ExtraArgs, Callback, Config)
#     170         return transfer.download_file(
#     171             bucket=Bucket, key=Key, filename=Filename,
# --> 172             extra_args=ExtraArgs, callback=Callback)
#     173
#     174
#
# ~/anaconda3/envs/mxnet_p36/lib/python3.6/site-packages/boto3/s3/transfer.py in download_file(self, bucket, key, filename, extra_args, callback)
#     305             bucket, key, filename, extra_args, subscribers)
#     306         try:
# --> 307             future.result()
#     308         # This is for backwards compatibility where when retries are
#     309         # exceeded we need to throw the same error from boto3 instead of
#
# ~/anaconda3/envs/mxnet_p36/lib/python3.6/site-packages/s3transfer/futures.py in result(self)
#     104             # however if a KeyboardInterrupt is raised we want want to exit
#     105             # out of this and propogate the exception.
# --> 106             return self._coordinator.result()
#     107         except KeyboardInterrupt as e:
#     108             self.cancel()
#
# ~/anaconda3/envs/mxnet_p36/lib/python3.6/site-packages/s3transfer/futures.py in result(self)
#     263         # final result.
#     264         if self._exception:
# --> 265             raise self._exception
#     266         return self._result
#     267
#
# ~/anaconda3/envs/mxnet_p36/lib/python3.6/site-packages/s3transfer/tasks.py in __call__(self)
#     124             # main() method.
#     125             if not self._transfer_coordinator.done():
# --> 126                 return self._execute_main(kwargs)
#     127         except Exception as e:
#     128             self._log_and_set_exception(e)
#
# ~/anaconda3/envs/mxnet_p36/lib/python3.6/site-packages/s3transfer/tasks.py in _execute_main(self, kwargs)
#     148         )
#     149
# --> 150         return_value = self._main(**kwargs)
#     151         # If the task is the final task, then set the TransferFuture's
#     152         # value to the return value from main().
#
# ~/anaconda3/envs/mxnet_p36/lib/python3.6/site-packages/s3transfer/download.py in _main(self, fileobj, data, offset)
#     571         :param offset: The offset to write the data to.
#     572         """
# --> 573         fileobj.seek(offset)
#     574         fileobj.write(data)
#     575
#
# ~/anaconda3/envs/mxnet_p36/lib/python3.6/site-packages/s3transfer/utils.py in seek(self, where)
#     359
#     360     def seek(self, where):
# --> 361         self._open_if_needed()
#     362         self._fileobj.seek(where)
#     363
#
# ~/anaconda3/envs/mxnet_p36/lib/python3.6/site-packages/s3transfer/utils.py in _open_if_needed(self)
#     342     def _open_if_needed(self):
#     343         if self._fileobj is None:
# --> 344             self._fileobj = self._open_function(self._filename, self._mode)
#     345             if self._start_byte != 0:
#     346                 self._fileobj.seek(self._start_byte)
#
# ~/anaconda3/envs/mxnet_p36/lib/python3.6/site-packages/s3transfer/utils.py in open(self, filename, mode)
#     257
#     258     def open(self, filename, mode):
# --> 259         return open(filename, mode)
#     260
#     261     def remove_file(self, filename):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'index/groundtruth_6GNMpHVFHkBi8Rr7PuLheLzLakyMp0E1aIKapXAUwhzpgo0Kr.r19Mne_W2ejdbiIBKOBmgNOust3xbRU74xpRvmj5hgeKt_7Ue8RuyDebfPdyFelGlHQdy3_817nuwXEY.0YpUhD9e4Hk3uawre_w--_etags_do_not_modify.tmp.b2e7b8a3'

# %%
data_dir = 'data'
images_dir = os.path.join(data_dir, 'logos')
train_images = glob.glob(images_dir + "/*")

# %%
print("We have {} images".format(len(train_images)))
# Out:
# We have 86 images

# %% [markdown]
# Let's see how they look like. We use matplotlib to plot 36 images from the dataset to get a feel for what they are

# %%
n_images = 36
cols = (int(math.sqrt(n_images)))*2
fig = plt.figure(figsize=(20,5))
for n, (image) in enumerate(train_images[:n_images]):
    image = plt.imread(image)
    a = fig.add_subplot(np.ceil(n_images/float(cols)), cols, n + 1)
    plt.imshow(image)
    plt.axis('off')
plt.subplots_adjust(wspace=0.06, hspace=0.06)
plt.show()

# %% [markdown]
# ### Bounding boxes

# %% [markdown]
# We've included the `output.manifest` file from our complete SageMaker GroundTruth labeling job on all images.

# %% [markdown]
# Let's dig in the info we have in the manifest file! On each image, there is one or more dice. We read this information from the `output.manifest` file.

# %%
image_info = []
with open(os.path.join(data_dir, 'logos-manifest/output.manifest')) as f:
    lines = f.readlines()
    for line in lines:
        image_info.append(json.loads(line[:-1]))

# %%
image_info
# Out:
# [{'source-ref': 's3://bcbs-logos/images (1).jpg',
#   'bcbs-logos': {'annotations': [{'class_id': 0,
#      'width': 27,
#      'top': 63,
#      'height': 32,
#      'left': 94}],
#    'image_size': [{'width': 318, 'depth': 3, 'height': 159}]},
#   'bcbs-logos-metadata': {'job-name': 'labeling-job/bcbs-logos',
#    'class-map': {'0': 'logo'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-12-03T20:13:21.115050',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://bcbs-logos/images (1).png',
#   'bcbs-logos': {'annotations': [{'class_id': 0,
#      'width': 116,
#      'top': 2,
#      'height': 60,
#      'left': 213}],
#    'image_size': [{'width': 343, 'depth': 3, 'height': 147}]},
#   'bcbs-logos-metadata': {'job-name': 'labeling-job/bcbs-logos',
#    'class-map': {'0': 'logo'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-12-03T20:08:16.829903',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://bcbs-logos/images (10).jpg',
#   'bcbs-logos': {'annotations': [{'class_id': 0,
#      'width': 57,
#      'top': 106,
#      'height': 36,
#      'left': 73}],
#    'image_size': [{'width': 318, 'depth': 3, 'height': 159}]},
#   'bcbs-logos-metadata': {'job-name': 'labeling-job/bcbs-logos',
#    'class-map': {'0': 'logo'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-12-03T20:09:35.969475',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://bcbs-logos/images (10).png',
#   'bcbs-logos': {'annotations': [{'class_id': 0,
#      'width': 43,
#      'top': 162,
#      'height': 26,
#      'left': 214}],
#    'image_size': [{'width': 259, 'depth': 3, 'height': 194}]},
#   'bcbs-logos-metadata': {'job-name': 'labeling-job/bcbs-logos',
#    'class-map': {'0': 'logo'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-12-03T20:13:20.649391',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://bcbs-logos/images (11).jpg',
#   'bcbs-logos': {'annotations': [{'class_id': 0,
#      'width': 64,
#      'top': 98,
#      'height': 34,
#      'left': 125}],
#    'image_size': [{'width': 318, 'depth': 3, 'height': 159}]},
#   'bcbs-logos-metadata': {'job-name': 'labeling-job/bcbs-logos',
#    'class-map': {'0': 'logo'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-12-03T20:09:35.190088',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://bcbs-logos/images (11).png',
#   'bcbs-logos': {'annotations': [{'class_id': 0,
#      'width': 45,
#      'top': 11,
#      'height': 28,
#      'left': 120}],
#    'image_size': [{'width': 197, 'depth': 3, 'height': 255}]},
#   'bcbs-logos-metadata': {'job-name': 'labeling-job/bcbs-logos',
#    'class-map': {'0': 'logo'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-12-03T20:10:53.797392',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://bcbs-logos/images (12).jpg',
#   'bcbs-logos': {'annotations': [{'class_id': 0,
#      'width': 33,
#      'top': 118,
#      'height': 23,
#      'left': 194}],
#    'image_size': [{'width': 318, 'depth': 3, 'height': 159}]},
#   'bcbs-logos-metadata': {'job-name': 'labeling-job/bcbs-logos',
#    'class-map': {'0': 'logo'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-12-03T20:13:21.894173',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://bcbs-logos/images (12).png',
#   'bcbs-logos': {'annotations': [{'class_id': 0,
#      'width': 42,
#      'top': 207,
#      'height': 28,
#      'left': 101}],
#    'image_size': [{'width': 180, 'depth': 3, 'height': 279}]},
#   'bcbs-logos-metadata': {'job-name': 'labeling-job/bcbs-logos',
#    'class-map': {'0': 'logo'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-12-03T20:08:18.178627',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://bcbs-logos/images (13).jpg',
#   'bcbs-logos': {'annotations': [{'class_id': 0,
#      'width': 33,
#      'top': 24,
#      'height': 23,
#      'left': 92}],
#    'image_size': [{'width': 193, 'depth': 3, 'height': 262}]},
#   'bcbs-logos-metadata': {'job-name': 'labeling-job/bcbs-logos',
#    'class-map': {'0': 'logo'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-12-03T20:08:16.707893',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://bcbs-logos/images (13).png',
#   'bcbs-logos': {'annotations': [{'class_id': 0,
#      'width': 172,
#      'top': 0,
#      'height': 78,
#      'left': 0}],
#    'image_size': [{'width': 600, 'depth': 3, 'height': 81}]},
#   'bcbs-logos-metadata': {'job-name': 'labeling-job/bcbs-logos',
#    'class-map': {'0': 'logo'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-12-03T20:07:00.102637',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://bcbs-logos/images (14).jpg',
#   'bcbs-logos': {'annotations': [{'class_id': 0,
#      'width': 38,
#      'top': 126,
#      'height': 28,
#      'left': 194}],
#    'image_size': [{'width': 318, 'depth': 3, 'height': 159}]},
#   'bcbs-logos-metadata': {'job-name': 'labeling-job/bcbs-logos',
#    'class-map': {'0': 'logo'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-12-03T20:09:35.653814',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://bcbs-logos/images (14).png',
#   'bcbs-logos': {'annotations': [{'class_id': 0,
#      'width': 103,
#      'top': 22,
#      'height': 54,
#      'left': 0}],
#    'image_size': [{'width': 346, 'depth': 3, 'height': 103}]},
#   'bcbs-logos-metadata': {'job-name': 'labeling-job/bcbs-logos',
#    'class-map': {'0': 'logo'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-12-03T20:12:07.656673',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://bcbs-logos/images (15).jpg',
#   'bcbs-logos': {'annotations': [{'class_id': 0,
#      'width': 31,
#      'top': 71,
#      'height': 19,
#      'left': 76}],
#    'image_size': [{'width': 310, 'depth': 3, 'height': 163}]},
#   'bcbs-logos-metadata': {'job-name': 'labeling-job/bcbs-logos',
#    'class-map': {'0': 'logo'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-12-03T20:08:18.310662',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://bcbs-logos/images (16).jpg',
#   'bcbs-logos': {'annotations': [{'class_id': 0,
#      'width': 29,
#      'top': 186,
#      'height': 20,
#      'left': 134}],
#    'image_size': [{'width': 225, 'depth': 3, 'height': 225}]},
#   'bcbs-logos-metadata': {'job-name': 'labeling-job/bcbs-logos',
#    'class-map': {'0': 'logo'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-12-03T20:10:53.248775',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://bcbs-logos/images (17).jpg',
#   'bcbs-logos': {'annotations': [{'class_id': 0,
#      'width': 32,
#      'top': 45,
#      'height': 19,
#      'left': 94}],
#    'image_size': [{'width': 308, 'depth': 3, 'height': 164}]},
#   'bcbs-logos-metadata': {'job-name': 'labeling-job/bcbs-logos',
#    'class-map': {'0': 'logo'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-12-03T20:14:32.851621',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://bcbs-logos/images (18).jpg',
#   'bcbs-logos': {'annotations': [{'class_id': 0,
#      'width': 170,
#      'top': 49,
#      'height': 83,
#      'left': 38}],
#    'image_size': [{'width': 250, 'depth': 3, 'height': 202}]},
#   'bcbs-logos-metadata': {'job-name': 'labeling-job/bcbs-logos',
#    'class-map': {'0': 'logo'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-12-03T20:10:52.216323',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://bcbs-logos/images (19).jpg',
#   'bcbs-logos': {'annotations': [{'class_id': 0,
#      'width': 38,
#      'top': 237,
#      'height': 23,
#      'left': 22}],
#    'image_size': [{'width': 166, 'depth': 3, 'height': 304}]},
#   'bcbs-logos-metadata': {'job-name': 'labeling-job/bcbs-logos',
#    'class-map': {'0': 'logo'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-12-03T20:09:35.413681',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://bcbs-logos/images (2).jpg',
#   'bcbs-logos': {'annotations': [{'class_id': 0,
#      'width': 50,
#      'top': 2,
#      'height': 27,
#      'left': 170}],
#    'image_size': [{'width': 380, 'depth': 3, 'height': 133}]},
#   'bcbs-logos-metadata': {'job-name': 'labeling-job/bcbs-logos',
#    'class-map': {'0': 'logo'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-12-03T20:14:33.118053',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://bcbs-logos/images (2).png',
#   'bcbs-logos': {'annotations': [{'class_id': 0,
#      'width': 171,
#      'top': 0,
#      'height': 86,
#      'left': 0}],
#    'image_size': [{'width': 404, 'depth': 3, 'height': 125}]},
#   'bcbs-logos-metadata': {'job-name': 'labeling-job/bcbs-logos',
#    'class-map': {'0': 'logo'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-12-03T20:10:53.089313',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://bcbs-logos/images (20).jpg',
#   'bcbs-logos': {'annotations': [{'class_id': 0,
#      'width': 22,
#      'top': 52,
#      'height': 14,
#      'left': 96}],
#    'image_size': [{'width': 260, 'depth': 3, 'height': 194}]},
#   'bcbs-logos-metadata': {'job-name': 'labeling-job/bcbs-logos',
#    'class-map': {'0': 'logo'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-12-03T20:06:59.530420',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://bcbs-logos/images (21).jpg',
#   'bcbs-logos': {'annotations': [{'class_id': 0,
#      'width': 35,
#      'top': 200,
#      'height': 17,
#      'left': 138}],
#    'image_size': [{'width': 197, 'depth': 3, 'height': 256}]},
#   'bcbs-logos-metadata': {'job-name': 'labeling-job/bcbs-logos',
#    'class-map': {'0': 'logo'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-12-03T20:09:35.072346',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://bcbs-logos/images (22).jpg',
#   'bcbs-logos': {'annotations': [{'class_id': 0,
#      'width': 61,
#      'top': 64,
#      'height': 33,
#      'left': 9}],
#    'image_size': [{'width': 205, 'depth': 3, 'height': 246}]},
#   'bcbs-logos-metadata': {'job-name': 'labeling-job/bcbs-logos',
#    'class-map': {'0': 'logo'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-12-03T20:13:21.485753',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://bcbs-logos/images (23).jpg',
#   'bcbs-logos': {'annotations': [{'class_id': 0,
#      'width': 70,
#      'top': 149,
#      'height': 50,
#      'left': 10}],
#    'image_size': [{'width': 246, 'depth': 3, 'height': 205}]},
#   'bcbs-logos-metadata': {'job-name': 'labeling-job/bcbs-logos',
#    'class-map': {'0': 'logo'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-12-03T20:08:16.525678',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://bcbs-logos/images (24).jpg',
#   'bcbs-logos': {'annotations': [{'class_id': 0,
#      'width': 18,
#      'top': 72,
#      'height': 14,
#      'left': 45}],
#    'image_size': [{'width': 264, 'depth': 3, 'height': 191}]},
#   'bcbs-logos-metadata': {'job-name': 'labeling-job/bcbs-logos',
#    'class-map': {'0': 'logo'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-12-03T20:05:44.892450',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://bcbs-logos/images (25).jpg',
#   'bcbs-logos': {'annotations': [{'class_id': 0,
#      'width': 85,
#      'top': 97,
#      'height': 49,
#      'left': 106}],
#    'image_size': [{'width': 300, 'depth': 3, 'height': 168}]},
#   'bcbs-logos-metadata': {'job-name': 'labeling-job/bcbs-logos',
#    'class-map': {'0': 'logo'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-12-03T20:10:52.955573',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://bcbs-logos/images (26).jpg',
#   'bcbs-logos': {'annotations': [{'class_id': 0,
#      'width': 300,
#      'top': 0,
#      'height': 161,
#      'left': 0}],
#    'image_size': [{'width': 300, 'depth': 3, 'height': 168}]},
#   'bcbs-logos-metadata': {'job-name': 'labeling-job/bcbs-logos',
#    'class-map': {'0': 'logo'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-12-03T20:10:53.933992',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://bcbs-logos/images (27).jpg',
#   'bcbs-logos': {'annotations': [{'class_id': 0,
#      'width': 59,
#      'top': 1,
#      'height': 35,
#      'left': 94}],
#    'image_size': [{'width': 300, 'depth': 3, 'height': 168}]},
#   'bcbs-logos-metadata': {'job-name': 'labeling-job/bcbs-logos',
#    'class-map': {'0': 'logo'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-12-03T20:06:59.991085',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://bcbs-logos/images (28).jpg',
#   'bcbs-logos': {'annotations': [{'class_id': 0,
#      'width': 236,
#      'top': 0,
#      'height': 117,
#      'left': 63}],
#    'image_size': [{'width': 350, 'depth': 3, 'height': 144}]},
#   'bcbs-logos-metadata': {'job-name': 'labeling-job/bcbs-logos',
#    'class-map': {'0': 'logo'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-12-03T20:15:43.760174',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://bcbs-logos/images (29).jpg',
#   'bcbs-logos': {'annotations': [{'class_id': 0,
#      'width': 36,
#      'top': 232,
#      'height': 22,
#      'left': 28}],
#    'image_size': [{'width': 166, 'depth': 3, 'height': 304}]},
#   'bcbs-logos-metadata': {'job-name': 'labeling-job/bcbs-logos',
#    'class-map': {'0': 'logo'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-12-03T20:06:59.691167',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://bcbs-logos/images (3).jpg',
#   'bcbs-logos': {'annotations': [{'class_id': 0,
#      'width': 169,
#      'top': 66,
#      'height': 101,
#      'left': 28}],
#    'image_size': [{'width': 225, 'depth': 3, 'height': 225}]},
#   'bcbs-logos-metadata': {'job-name': 'labeling-job/bcbs-logos',
#    'class-map': {'0': 'logo'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-12-03T20:05:45.130215',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://bcbs-logos/images (3).png',
#   'bcbs-logos': {'annotations': [{'class_id': 0,
#      'width': 32,
#      'top': 5,
#      'height': 17,
#      'left': 14}],
#    'image_size': [{'width': 197, 'depth': 3, 'height': 256}]},
#   'bcbs-logos-metadata': {'job-name': 'labeling-job/bcbs-logos',
#    'class-map': {'0': 'logo'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-12-03T20:10:53.487134',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://bcbs-logos/images (30).jpg',
#   'bcbs-logos': {'annotations': [{'class_id': 0,
#      'width': 58,
#      'top': 86,
#      'height': 38,
#      'left': 54}],
#    'image_size': [{'width': 300, 'depth': 3, 'height': 168}]},
#   'bcbs-logos-metadata': {'job-name': 'labeling-job/bcbs-logos',
#    'class-map': {'0': 'logo'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-12-03T20:09:36.501728',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://bcbs-logos/images (31).jpg',
#   'bcbs-logos': {'annotations': [{'class_id': 0,
#      'width': 71,
#      'top': 21,
#      'height': 41,
#      'left': 41}],
#    'image_size': [{'width': 300, 'depth': 3, 'height': 168}]},
#   'bcbs-logos-metadata': {'job-name': 'labeling-job/bcbs-logos',
#    'class-map': {'0': 'logo'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-12-03T20:15:43.496222',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://bcbs-logos/images (32).jpg',
#   'bcbs-logos': {'annotations': [{'class_id': 0,
#      'width': 32,
#      'top': 72,
#      'height': 18,
#      'left': 264}],
#    'image_size': [{'width': 300, 'depth': 3, 'height': 168}]},
#   'bcbs-logos-metadata': {'job-name': 'labeling-job/bcbs-logos',
#    'class-map': {'0': 'logo'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-12-03T20:12:07.911605',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://bcbs-logos/images (33).jpg',
#   'bcbs-logos': {'annotations': [{'class_id': 0,
#      'width': 229,
#      'top': 5,
#      'height': 120,
#      'left': 16}],
#    'image_size': [{'width': 268, 'depth': 3, 'height': 188}]},
#   'bcbs-logos-metadata': {'job-name': 'labeling-job/bcbs-logos',
#    'class-map': {'0': 'logo'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-12-03T20:10:52.729451',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://bcbs-logos/images (34).jpg',
#   'bcbs-logos': {'annotations': [{'class_id': 0,
#      'width': 139,
#      'top': 17,
#      'height': 72,
#      'left': 65}],
#    'image_size': [{'width': 268, 'depth': 3, 'height': 188}]},
#   'bcbs-logos-metadata': {'job-name': 'labeling-job/bcbs-logos',
#    'class-map': {'0': 'logo'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-12-03T20:13:20.976328',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://bcbs-logos/images (35).jpg',
#   'bcbs-logos': {'annotations': [{'class_id': 0,
#      'width': 42,
#      'top': 43,
#      'height': 26,
#      'left': 80}],
#    'image_size': [{'width': 275, 'depth': 3, 'height': 183}]},
#   'bcbs-logos-metadata': {'job-name': 'labeling-job/bcbs-logos',
#    'class-map': {'0': 'logo'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-12-03T20:15:43.254962',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://bcbs-logos/images (36).jpg',
#   'bcbs-logos': {'annotations': [{'class_id': 0,
#      'width': 50,
#      'top': 111,
#      'height': 28,
#      'left': 112}],
#    'image_size': [{'width': 248, 'depth': 3, 'height': 203}]},
#   'bcbs-logos-metadata': {'job-name': 'labeling-job/bcbs-logos',
#    'class-map': {'0': 'logo'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-12-03T20:15:43.628453',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://bcbs-logos/images (37).jpg',
#   'bcbs-logos': {'annotations': [{'class_id': 0,
#      'width': 16,
#      'top': 0,
#      'height': 16,
#      'left': 1}],
#    'image_size': [{'width': 192, 'depth': 3, 'height': 263}]},
#   'bcbs-logos-metadata': {'job-name': 'labeling-job/bcbs-logos',
#    'class-map': {'0': 'logo'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-12-03T20:05:44.672062',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://bcbs-logos/images (38).jpg',
#   'bcbs-logos': {'annotations': [{'class_id': 0,
#      'width': 230,
#      'top': 0,
#      'height': 115,
#      'left': 0}],
#    'image_size': [{'width': 232, 'depth': 3, 'height': 217}]},
#   'bcbs-logos-metadata': {'job-name': 'labeling-job/bcbs-logos',
#    'class-map': {'0': 'logo'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-12-03T20:08:17.396271',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://bcbs-logos/images (39).jpg',
#   'bcbs-logos': {'annotations': [{'class_id': 0,
#      'width': 29,
#      'top': 80,
#      'height': 22,
#      'left': 42}],
#    'image_size': [{'width': 275, 'depth': 3, 'height': 183}]},
#   'bcbs-logos-metadata': {'job-name': 'labeling-job/bcbs-logos',
#    'class-map': {'0': 'logo'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-12-03T20:05:45.243836',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://bcbs-logos/images (4).jpg',
#   'bcbs-logos': {'annotations': [{'class_id': 0,
#      'width': 29,
#      'top': 190,
#      'height': 21,
#      'left': 129}],
#    'image_size': [{'width': 225, 'depth': 3, 'height': 225}]},
#   'bcbs-logos-metadata': {'job-name': 'labeling-job/bcbs-logos',
#    'class-map': {'0': 'logo'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-12-03T20:15:43.112721',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://bcbs-logos/images (4).png',
#   'bcbs-logos': {'annotations': [{'class_id': 0,
#      'width': 91,
#      'top': 51,
#      'height': 53,
#      'left': 8}],
#    'image_size': [{'width': 317, 'depth': 3, 'height': 159}]},
#   'bcbs-logos-metadata': {'job-name': 'labeling-job/bcbs-logos',
#    'class-map': {'0': 'logo'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-12-03T20:10:52.413723',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://bcbs-logos/images (40).jpg',
#   'bcbs-logos': {'annotations': [{'class_id': 0,
#      'width': 57,
#      'top': 130,
#      'height': 29,
#      'left': 10}],
#    'image_size': [{'width': 275, 'depth': 3, 'height': 183}]},
#   'bcbs-logos-metadata': {'job-name': 'labeling-job/bcbs-logos',
#    'class-map': {'0': 'logo'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-12-03T20:14:34.110131',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://bcbs-logos/images (41).jpg',
#   'bcbs-logos': {'annotations': [{'class_id': 0,
#      'width': 93,
#      'top': 75,
#      'height': 47,
#      'left': 138}],
#    'image_size': [{'width': 275, 'depth': 3, 'height': 183}]},
#   'bcbs-logos-metadata': {'job-name': 'labeling-job/bcbs-logos',
#    'class-map': {'0': 'logo'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-12-03T20:15:43.889156',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://bcbs-logos/images (42).jpg',
#   'bcbs-logos': {'annotations': [{'class_id': 0,
#      'width': 29,
#      'top': 0,
#      'height': 14,
#      'left': 6}],
#    'image_size': [{'width': 172, 'depth': 3, 'height': 293}]},
#   'bcbs-logos-metadata': {'job-name': 'labeling-job/bcbs-logos',
#    'class-map': {'0': 'logo'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-12-03T20:06:59.415253',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://bcbs-logos/images (43).jpg',
#   'bcbs-logos': {'annotations': [{'class_id': 0,
#      'width': 65,
#      'top': 109,
#      'height': 38,
#      'left': 135}],
#    'image_size': [{'width': 318, 'depth': 3, 'height': 159}]},
#   'bcbs-logos-metadata': {'job-name': 'labeling-job/bcbs-logos',
#    'class-map': {'0': 'logo'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-12-03T20:09:36.368444',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://bcbs-logos/images (44).jpg',
#   'bcbs-logos': {'annotations': [{'class_id': 0,
#      'width': 48,
#      'top': 139,
#      'height': 26,
#      'left': 1}],
#    'image_size': [{'width': 275, 'depth': 3, 'height': 183}]},
#   'bcbs-logos-metadata': {'job-name': 'labeling-job/bcbs-logos',
#    'class-map': {'0': 'logo'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-12-03T20:12:07.801779',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://bcbs-logos/images (45).jpg',
#   'bcbs-logos': {'annotations': [{'class_id': 0,
#      'width': 28,
#      'top': 158,
#      'height': 19,
#      'left': 46}],
#    'image_size': [{'width': 280, 'depth': 3, 'height': 180}]},
#   'bcbs-logos-metadata': {'job-name': 'labeling-job/bcbs-logos',
#    'class-map': {'0': 'logo'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-12-03T20:10:52.834058',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://bcbs-logos/images (46).jpg',
#   'bcbs-logos': {'annotations': [{'class_id': 0,
#      'width': 42,
#      'top': 232,
#      'height': 30,
#      'left': 24}],
#    'image_size': [{'width': 185, 'depth': 3, 'height': 272}]},
#   'bcbs-logos-metadata': {'job-name': 'labeling-job/bcbs-logos',
#    'class-map': {'0': 'logo'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-12-03T20:14:33.242613',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://bcbs-logos/images (47).jpg',
#   'bcbs-logos': {'annotations': [{'class_id': 0,
#      'width': 74,
#      'top': 27,
#      'height': 38,
#      'left': 11}],
#    'image_size': [{'width': 396, 'depth': 3, 'height': 127}]},
#   'bcbs-logos-metadata': {'job-name': 'labeling-job/bcbs-logos',
#    'class-map': {'0': 'logo'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-12-03T20:09:36.593413',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://bcbs-logos/images (48).jpg',
#   'bcbs-logos': {'annotations': [{'class_id': 0,
#      'width': 51,
#      'top': 18,
#      'height': 30,
#      'left': 27}],
#    'image_size': [{'width': 310, 'depth': 3, 'height': 162}]},
#   'bcbs-logos-metadata': {'job-name': 'labeling-job/bcbs-logos',
#    'class-map': {'0': 'logo'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-12-03T20:13:20.782757',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://bcbs-logos/images (49).jpg',
#   'bcbs-logos': {'annotations': [{'class_id': 0,
#      'width': 107,
#      'top': 85,
#      'height': 59,
#      'left': 175}],
#    'image_size': [{'width': 303, 'depth': 3, 'height': 166}]},
#   'bcbs-logos-metadata': {'job-name': 'labeling-job/bcbs-logos',
#    'class-map': {'0': 'logo'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-12-03T20:05:45.035705',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://bcbs-logos/images (5).jpg',
#   'bcbs-logos': {'annotations': [{'class_id': 0,
#      'width': 31,
#      'top': 120,
#      'height': 24,
#      'left': 7}],
#    'image_size': [{'width': 318, 'depth': 3, 'height': 159}]},
#   'bcbs-logos-metadata': {'job-name': 'labeling-job/bcbs-logos',
#    'class-map': {'0': 'logo'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-12-03T20:06:59.871950',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://bcbs-logos/images (5).png',
#   'bcbs-logos': {'annotations': [{'class_id': 0,
#      'width': 53,
#      'top': 126,
#      'height': 28,
#      'left': 74}],
#    'image_size': [{'width': 303, 'depth': 3, 'height': 166}]},
#   'bcbs-logos-metadata': {'job-name': 'labeling-job/bcbs-logos',
#    'class-map': {'0': 'logo'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-12-03T20:08:17.941753',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://bcbs-logos/images (50).jpg',
#   'bcbs-logos': {'annotations': [{'class_id': 0,
#      'width': 46,
#      'top': 163,
#      'height': 27,
#      'left': 211}],
#    'image_size': [{'width': 259, 'depth': 3, 'height': 194}]},
#   'bcbs-logos-metadata': {'job-name': 'labeling-job/bcbs-logos',
#    'class-map': {'0': 'logo'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-12-03T20:05:44.288230',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://bcbs-logos/images (51).jpg',
#   'bcbs-logos': {'annotations': [{'class_id': 0,
#      'width': 190,
#      'top': 0,
#      'height': 94,
#      'left': 58}],
#    'image_size': [{'width': 299, 'depth': 3, 'height': 168}]},
#   'bcbs-logos-metadata': {'job-name': 'labeling-job/bcbs-logos',
#    'class-map': {'0': 'logo'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-12-03T20:08:18.068849',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://bcbs-logos/images (52).jpg',
#   'bcbs-logos': {'annotations': [{'class_id': 0,
#      'width': 172,
#      'top': 19,
#      'height': 109,
#      'left': 55}],
#    'image_size': [{'width': 299, 'depth': 3, 'height': 168}]},
#   'bcbs-logos-metadata': {'job-name': 'labeling-job/bcbs-logos',
#    'class-map': {'0': 'logo'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-12-03T20:05:44.155593',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://bcbs-logos/images (53).jpg',
#   'bcbs-logos': {'annotations': [{'class_id': 0,
#      'width': 26,
#      'top': 117,
#      'height': 13,
#      'left': 36}],
#    'image_size': [{'width': 168, 'depth': 3, 'height': 299}]},
#   'bcbs-logos-metadata': {'job-name': 'labeling-job/bcbs-logos',
#    'class-map': {'0': 'logo'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-12-03T20:14:33.362350',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://bcbs-logos/images (54).jpg',
#   'bcbs-logos': {'annotations': [{'class_id': 0,
#      'width': 23,
#      'top': 66,
#      'height': 19,
#      'left': 43}],
#    'image_size': [{'width': 259, 'depth': 3, 'height': 194}]},
#   'bcbs-logos-metadata': {'job-name': 'labeling-job/bcbs-logos',
#    'class-map': {'0': 'logo'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-12-03T20:08:17.796708',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://bcbs-logos/images (55).jpg',
#   'bcbs-logos': {'annotations': [{'class_id': 0,
#      'width': 27,
#      'top': 36,
#      'height': 18,
#      'left': 23}],
#    'image_size': [{'width': 168, 'depth': 3, 'height': 299}]},
#   'bcbs-logos-metadata': {'job-name': 'labeling-job/bcbs-logos',
#    'class-map': {'0': 'logo'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-12-03T20:08:17.525175',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://bcbs-logos/images (56).jpg',
#   'bcbs-logos': {'annotations': [{'class_id': 0,
#      'width': 19,
#      'top': 151,
#      'height': 18,
#      'left': 51}],
#    'image_size': [{'width': 259, 'depth': 3, 'height': 194}]},
#   'bcbs-logos-metadata': {'job-name': 'labeling-job/bcbs-logos',
#    'class-map': {'0': 'logo'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-12-03T20:08:17.089219',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://bcbs-logos/images (57).jpg',
#   'bcbs-logos': {'annotations': [{'class_id': 0,
#      'width': 80,
#      'top': 52,
#      'height': 42,
#      'left': 20}],
#    'image_size': [{'width': 399, 'depth': 3, 'height': 126}]},
#   'bcbs-logos-metadata': {'job-name': 'labeling-job/bcbs-logos',
#    'class-map': {'0': 'logo'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-12-03T20:13:21.643102',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://bcbs-logos/images (58).jpg',
#   'bcbs-logos': {'annotations': [{'class_id': 0,
#      'width': 44,
#      'top': 63,
#      'height': 27,
#      'left': 128}],
#    'image_size': [{'width': 312, 'depth': 3, 'height': 161}]},
#   'bcbs-logos-metadata': {'job-name': 'labeling-job/bcbs-logos',
#    'class-map': {'0': 'logo'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-12-03T20:09:35.541094',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://bcbs-logos/images (59).jpg',
#   'bcbs-logos': {'annotations': [{'class_id': 0,
#      'width': 23,
#      'top': 38,
#      'height': 13,
#      'left': 184},
#     {'class_id': 0, 'width': 22, 'top': 51, 'height': 11, 'left': 113}],
#    'image_size': [{'width': 342, 'depth': 3, 'height': 147}]},
#   'bcbs-logos-metadata': {'job-name': 'labeling-job/bcbs-logos',
#    'class-map': {'0': 'logo'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}, {'confidence': 0.09}],
#    'creation-date': '2019-12-03T20:10:53.635371',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://bcbs-logos/images (6).jpg',
#   'bcbs-logos': {'annotations': [{'class_id': 0,
#      'width': 30,
#      'top': 50,
#      'height': 17,
#      'left': 108}],
#    'image_size': [{'width': 200, 'depth': 3, 'height': 253}]},
#   'bcbs-logos-metadata': {'job-name': 'labeling-job/bcbs-logos',
#    'class-map': {'0': 'logo'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-12-03T20:09:36.112332',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://bcbs-logos/images (6).png',
#   'bcbs-logos': {'annotations': [{'class_id': 0,
#      'width': 191,
#      'top': 1,
#      'height': 93,
#      'left': 69}],
#    'image_size': [{'width': 331, 'depth': 3, 'height': 152}]},
#   'bcbs-logos-metadata': {'job-name': 'labeling-job/bcbs-logos',
#    'class-map': {'0': 'logo'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-12-03T20:05:44.419232',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://bcbs-logos/images (60).jpg',
#   'bcbs-logos': {'annotations': [{'class_id': 0,
#      'width': 222,
#      'top': 1,
#      'height': 103,
#      'left': 11}],
#    'image_size': [{'width': 259, 'depth': 3, 'height': 194}]},
#   'bcbs-logos-metadata': {'job-name': 'labeling-job/bcbs-logos',
#    'class-map': {'0': 'logo'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-12-03T20:13:21.367489',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://bcbs-logos/images (61).jpg',
#   'bcbs-logos': {'annotations': [{'class_id': 0,
#      'width': 256,
#      'top': 0,
#      'height': 134,
#      'left': 0}],
#    'image_size': [{'width': 259, 'depth': 3, 'height': 194}]},
#   'bcbs-logos-metadata': {'job-name': 'labeling-job/bcbs-logos',
#    'class-map': {'0': 'logo'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-12-03T20:14:34.001848',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://bcbs-logos/images (62).jpg',
#   'bcbs-logos': {'annotations': [{'class_id': 0,
#      'width': 77,
#      'top': 112,
#      'height': 40,
#      'left': 210}],
#    'image_size': [{'width': 294, 'depth': 3, 'height': 171}]},
#   'bcbs-logos-metadata': {'job-name': 'labeling-job/bcbs-logos',
#    'class-map': {'0': 'logo'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-12-03T20:09:35.312138',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://bcbs-logos/images (63).jpg',
#   'bcbs-logos': {'annotations': [],
#    'image_size': [{'width': 179, 'depth': 3, 'height': 281}]},
#   'bcbs-logos-metadata': {'job-name': 'labeling-job/bcbs-logos',
#    'class-map': {},
#    'human-annotated': 'yes',
#    'objects': [],
#    'creation-date': '2019-12-03T20:09:35.807047',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://bcbs-logos/images (64).jpg',
#   'bcbs-logos': {'annotations': [{'class_id': 0,
#      'width': 52,
#      'top': 154,
#      'height': 30,
#      'left': 153}],
#    'image_size': [{'width': 224, 'depth': 3, 'height': 224}]},
#   'bcbs-logos-metadata': {'job-name': 'labeling-job/bcbs-logos',
#    'class-map': {'0': 'logo'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-12-03T20:12:08.068626',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://bcbs-logos/images (65).jpg',
#   'bcbs-logos': {'annotations': [{'class_id': 0,
#      'width': 73,
#      'top': 6,
#      'height': 38,
#      'left': 123}],
#    'image_size': [{'width': 517, 'depth': 3, 'height': 97}]},
#   'bcbs-logos-metadata': {'job-name': 'labeling-job/bcbs-logos',
#    'class-map': {'0': 'logo'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-12-03T20:14:32.985685',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://bcbs-logos/images (66).jpg',
#   'bcbs-logos': {'annotations': [{'class_id': 0,
#      'width': 32,
#      'top': 58,
#      'height': 19,
#      'left': 116}],
#    'image_size': [{'width': 299, 'depth': 3, 'height': 168}]},
#   'bcbs-logos-metadata': {'job-name': 'labeling-job/bcbs-logos',
#    'class-map': {'0': 'logo'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-12-03T20:12:07.133264',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://bcbs-logos/images (67).jpg',
#   'bcbs-logos': {'annotations': [{'class_id': 0,
#      'width': 54,
#      'top': 62,
#      'height': 27,
#      'left': 155}],
#    'image_size': [{'width': 224, 'depth': 3, 'height': 224}]},
#   'bcbs-logos-metadata': {'job-name': 'labeling-job/bcbs-logos',
#    'class-map': {'0': 'logo'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-12-03T20:08:17.250630',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://bcbs-logos/images (68).jpg',
#   'bcbs-logos': {'annotations': [{'class_id': 0,
#      'width': 36,
#      'top': 217,
#      'height': 23,
#      'left': 161}],
#    'image_size': [{'width': 197, 'depth': 3, 'height': 255}]},
#   'bcbs-logos-metadata': {'job-name': 'labeling-job/bcbs-logos',
#    'class-map': {'0': 'logo'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-12-03T20:14:33.531855',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://bcbs-logos/images (69).jpg',
#   'bcbs-logos': {'annotations': [{'class_id': 0,
#      'width': 56,
#      'top': 90,
#      'height': 29,
#      'left': 101}],
#    'image_size': [{'width': 259, 'depth': 3, 'height': 194}]},
#   'bcbs-logos-metadata': {'job-name': 'labeling-job/bcbs-logos',
#    'class-map': {'0': 'logo'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-12-03T20:15:43.370476',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://bcbs-logos/images (7).jpg',
#   'bcbs-logos': {'annotations': [{'class_id': 0,
#      'width': 72,
#      'top': 162,
#      'height': 44,
#      'left': 2}],
#    'image_size': [{'width': 225, 'depth': 3, 'height': 225}]},
#   'bcbs-logos-metadata': {'job-name': 'labeling-job/bcbs-logos',
#    'class-map': {'0': 'logo'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-12-03T20:05:44.556564',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://bcbs-logos/images (7).png',
#   'bcbs-logos': {'annotations': [{'class_id': 0,
#      'width': 191,
#      'top': 0,
#      'height': 93,
#      'left': 329}],
#    'image_size': [{'width': 523, 'depth': 3, 'height': 96}]},
#   'bcbs-logos-metadata': {'job-name': 'labeling-job/bcbs-logos',
#    'class-map': {'0': 'logo'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-12-03T20:12:07.497394',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://bcbs-logos/images (70).jpg',
#   'bcbs-logos': {'annotations': [{'class_id': 0,
#      'width': 61,
#      'top': 66,
#      'height': 37,
#      'left': 135}],
#    'image_size': [{'width': 464, 'depth': 3, 'height': 108}]},
#   'bcbs-logos-metadata': {'job-name': 'labeling-job/bcbs-logos',
#    'class-map': {'0': 'logo'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-12-03T20:12:07.247459',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://bcbs-logos/images (8).jpg',
#   'bcbs-logos': {'annotations': [{'class_id': 0,
#      'width': 32,
#      'top': 192,
#      'height': 20,
#      'left': 127}],
#    'image_size': [{'width': 225, 'depth': 3, 'height': 225}]},
#   'bcbs-logos-metadata': {'job-name': 'labeling-job/bcbs-logos',
#    'class-map': {'0': 'logo'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-12-03T20:10:52.623084',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://bcbs-logos/images (8).png',
#   'bcbs-logos': {'annotations': [{'class_id': 0,
#      'width': 201,
#      'top': 0,
#      'height': 98,
#      'left': 0}],
#    'image_size': [{'width': 492, 'depth': 3, 'height': 102}]},
#   'bcbs-logos-metadata': {'job-name': 'labeling-job/bcbs-logos',
#    'class-map': {'0': 'logo'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-12-03T20:13:21.776279',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://bcbs-logos/images (9).jpg',
#   'bcbs-logos': {'annotations': [{'class_id': 0,
#      'width': 65,
#      'top': 134,
#      'height': 34,
#      'left': 12}],
#    'image_size': [{'width': 225, 'depth': 3, 'height': 225}]},
#   'bcbs-logos-metadata': {'job-name': 'labeling-job/bcbs-logos',
#    'class-map': {'0': 'logo'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-12-03T20:12:07.377235',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://bcbs-logos/images (9).png',
#   'bcbs-logos': {'annotations': [{'class_id': 0,
#      'width': 29,
#      'top': 138,
#      'height': 18,
#      'left': 5}],
#    'image_size': [{'width': 303, 'depth': 3, 'height': 166}]},
#   'bcbs-logos-metadata': {'job-name': 'labeling-job/bcbs-logos',
#    'class-map': {'0': 'logo'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-12-03T20:08:17.662620',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://bcbs-logos/images.jpg',
#   'bcbs-logos': {'annotations': [{'class_id': 0,
#      'width': 39,
#      'top': 98,
#      'height': 21,
#      'left': 266}],
#    'image_size': [{'width': 392, 'depth': 3, 'height': 129}]},
#   'bcbs-logos-metadata': {'job-name': 'labeling-job/bcbs-logos',
#    'class-map': {'0': 'logo'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-12-03T20:09:36.259111',
#    'type': 'groundtruth/object-detection'}},
#  {'source-ref': 's3://bcbs-logos/images.png',
#   'bcbs-logos': {'annotations': [{'class_id': 0,
#      'width': 95,
#      'top': 53,
#      'height': 50,
#      'left': 0}],
#    'image_size': [{'width': 318, 'depth': 3, 'height': 159}]},
#   'bcbs-logos-metadata': {'job-name': 'labeling-job/bcbs-logos',
#    'class-map': {'0': 'logo'},
#    'human-annotated': 'yes',
#    'objects': [{'confidence': 0.09}],
#    'creation-date': '2019-12-03T20:13:21.253319',
#    'type': 'groundtruth/object-detection'}}]

# %% [markdown]
# For each image, we have the following information:

# %%
info = image_info[10]
#task = 'dice-labeling'
info
# Out:
# {'source-ref': 's3://bcbs-logos/images (14).jpg',
#  'bcbs-logos': {'annotations': [{'class_id': 0,
#     'width': 38,
#     'top': 126,
#     'height': 28,
#     'left': 194}],
#   'image_size': [{'width': 318, 'depth': 3, 'height': 159}]},
#  'bcbs-logos-metadata': {'job-name': 'labeling-job/bcbs-logos',
#   'class-map': {'0': 'logo'},
#   'human-annotated': 'yes',
#   'objects': [{'confidence': 0.09}],
#   'creation-date': '2019-12-03T20:09:35.653814',
#   'type': 'groundtruth/object-detection'}}

# %% [markdown]
# We can access the name of the different classes corresponding to the class index as given by the SageMaker ground-truth labeling job

# %%
#class_map = info[task+'-metadata']['class-map']
#classes = [class_map[str(i)] for i in range(len(class_map))]
#classes

# %% [markdown]
# We can read the data from this dictionnary to use it to draw a bounding box around the dice using the OpenCV library

# %%
image = plt.imread(os.path.join(images_dir, info['source-ref'].split('/')[-1]))

# %%
images_dir
# Out:
# 'data/logos'

# %%
info
# Out:
# {'source-ref': 's3://tdelteil-sagemaker-reinvent2019-worksop/dice/IMG_20191112_101245_1.jpg',
#  'dice-labeling': {'annotations': [{'class_id': 3,
#     'width': 61,
#     'top': 72,
#     'height': 63,
#     'left': 230},
#    {'class_id': 3, 'width': 69, 'top': 116, 'height': 65, 'left': 419},
#    {'class_id': 4, 'width': 54, 'top': 16, 'height': 60, 'left': 133},
#    {'class_id': 4, 'width': 54, 'top': 21, 'height': 57, 'left': 38},
#    {'class_id': 5, 'width': 68, 'top': 166, 'height': 69, 'left': 105}],
#   'image_size': [{'width': 512, 'depth': 3, 'height': 384}]},
#  'dice-labeling-metadata': {'job-name': 'labeling-job/dice-labeling',
#   'class-map': {'1': 'two',
#    '0': 'one',
#    '3': 'four',
#    '2': 'three',
#    '5': 'six',
#    '4': 'five',
#    '6': 'unclear'},
#   'human-annotated': 'yes',
#   'objects': [{'confidence': 0.09},
#    {'confidence': 0.09},
#    {'confidence': 0.09},
#    {'confidence': 0.09},
#    {'confidence': 0.09}],
#   'creation-date': '2019-11-12T22:03:36.489415',
#   'type': 'groundtruth/object-detection'}}

# %%
boxes = info['bcbs-logos']['annotations']
for box in boxes:
    cv2.rectangle(image, (int(box['left']), int(box['top'])), (int(box['left']+box['width']), int(box['top']+box['height'])), (0,255,0), 3)
    cv2.putText(image, str(box['class_id']+1), (int(box['left']+box['width']), int(box['top']+box['height'])), 1, 3, (255,0,0), 3)

# %%
o = plt.imshow(image)

# %% [markdown]
# ## Fine-tuning an object detection model
#
# Now that we have explored the dataset, let's run a training job on SageMaker

# %%
import glob
import os
import re
import subprocess
import sys
import time
from time import gmtime, strftime

import boto3
import sagemaker
import numpy as np
from utils import get_execution_role

# %% [markdown]
# The training script used to train the model:

# %%
# !pygmentize src/train_yolo.py
# Out:
# import argparse
# import glob
# import json
# import math
# import os
# import random
# import subprocess
# import time
# import zipfile
#
# try:
#     subprocess.run(["python", "-m", "pip", "install", "opencv-python"])
#     subprocess.run(["python", "-m", "pip", "install", "gluoncv", "--pre"])
#     import cv2
#     import gluoncv as gcv
#     from gluoncv.utils import viz
#     from gluoncv.data.batchify import Tuple, Stack, Pad
#     from gluoncv.utils.metrics.voc_detection import VOC07MApMetric
#     from gluoncv.data.batchify import Tuple, Stack, Pad
#     from gluoncv.data.transforms.presets.yolo import YOLO3DefaultTrainTransform
#     from gluoncv.data.transforms.presets.yolo import YOLO3DefaultValTransform
# except:
#     print("Cannot install dependencies")
#
#
# import mxnet as mx
# from mxnet import gluon, nd, autograd
# import numpy as np
#
# class GroundTruthDetectionDataset(gluon.data.Dataset):
#     """
#     Custom Dataset to handle the GroundTruthDetectionDataset
#     """
#     def __init__(self, data_path='data', split='train', task='dice-labeling'):
#         """
#         Parameters
#         ---------
#         data_path: str, Path to the data folder, default 'data'
#         split: str, Which dataset split to request, default 'train'
#
#         """
#         self.data_path = data_path
#         self.image_info = []
#         self.task = task
#         with open(os.path.join(data_path, 'manifest', 'output.manifest')) as f:
#             lines = f.readlines()
#             for line in lines:
#                 info = json.loads(line[:-1])
#                 if len(info[self.task]['annotations']):
#                     self.image_info.append(info)
#
#         assert split in ['train', 'test', 'val']
#         random.seed(1234)
#         random.shuffle(self.image_info)
#         l = len(self.image_info)
#         if split == 'train':
#             self.image_info = self.image_info[:int(0.9*l)]
#         if split == 'val':
#             self.image_info = self.image_info[int(0.9*l):int(l)]
#
#
#     def __getitem__(self, idx):
#         """
#         Parameters
#         ---------
#         idx: int, index requested
#         Returns
#         -------
#         image: nd.NDArray
#             The image
#         label: np.NDArray bounding box labels of the form [[x1,y1, x2, y2, class], ...]
#         """
#         info = self.image_info[idx]
#         image = mx.image.imread(os.path.join(self.data_path, 'images', info['source-ref'].split('/')[-1]))
#         boxes = info[self.task]['annotations']
#         label = []
#         for box in boxes:
#             label.append([box['left'], box['top'], box['left']+box['width'], box['top']+box['height'], box['class_id']])
#
#         return image, np.array(label)
#
#     def __len__(self):
#         return len(self.image_info)
#
#
# def get_dataloader(net, train_dataset, image_h, image_w, batch_size, num_workers):
#     """
#     Get dataloader.
#     """
#
#     batchify_fn = Tuple(*([Stack() for _ in range(6)] + [Pad(axis=0, pad_val=-1) for _ in range(1)]))  # stack image, all targets generated
#
#     train_loader = gluon.data.DataLoader(
#         train_dataset.transform(YOLO3DefaultTrainTransform(image_w, image_h, net, mixup=False)),
#         batch_size, True, batchify_fn=batchify_fn, last_batch='rollover', num_workers=num_workers)
#
#     val_transform = YOLO3DefaultValTransform(image_w, image_h)
#     batchify_fn = Tuple(Stack(), Pad(pad_val=-1))
#     val_loader = gluon.data.DataLoader(
#         validation_dataset.transform(val_transform),
#         batch_size, False, batchify_fn=batchify_fn, last_batch='keep', num_workers=num_workers)
#
#     return train_loader, val_loader
#
# def parse_args():
#     """
#     Get the arguments
#     """
#
#     parser = argparse.ArgumentParser()
#
#
#     parser.add_argument('--batch_size', type=int, default=8)
#     parser.add_argument('--epochs', type=int, default=1)
#     parser.add_argument('--lr', type=float, default=0.001)
#     parser.add_argument('--lr_factor', type=float, default=0.5)
#     parser.add_argument('--class_factor', type=float, default=1)
#     parser.add_argument('--wd', type=float, default=0.00001)
#     parser.add_argument('--model', type=str, default="yolo3_mobilenet1.0_coco")
#
#
#     parser.add_argument('--model_dir', type=str, default=os.environ['SM_MODEL_DIR'])
#     parser.add_argument('--train', type=str, default=os.environ['SM_CHANNEL_TRAIN'])
#
#     parser.add_argument('--current_host', type=str, default=os.environ['SM_CURRENT_HOST'])
#     parser.add_argument('--hosts', type=list, default=json.loads(os.environ['SM_HOSTS']))
#
#     return parser.parse_args()
#
#
# def validate(net, val_data, ctx, classes):
#     """
#     Compute the mAP for the network on the validation data
#     """
#     metric = VOC07MApMetric(iou_thresh=0.5, class_names=classes)
#     net.set_nms(nms_thresh=0.2, nms_topk=400, post_nms=100)
#     for ib, batch in enumerate(val_data):
#
#         data = gluon.utils.split_and_load(batch[0], ctx_list=ctx, batch_axis=0, even_split=False)
#         label = gluon.utils.split_and_load(batch[1], ctx_list=ctx, batch_axis=0, even_split=False)
#         det_bboxes, det_ids, det_scores = [],[],[]
#         gt_bboxes,gt_ids = [], []
#
#         for x, y in zip(data, label):
#             ids, scores, bboxes = net(x)
#             det_ids.append(ids)
#             det_scores.append(scores)
#             det_bboxes.append(bboxes.clip(0, batch[0].shape[2]))
#             gt_ids.append(y.slice_axis(axis=-1, begin=4, end=5))
#             gt_bboxes.append(y.slice_axis(axis=-1, begin=0, end=4))
#
#             metric.update(det_bboxes, det_ids, det_scores, gt_bboxes, gt_ids)
#     return metric.get()
#
# if __name__ == '__main__':
#
#     args = parse_args()
#
#     ########################
#     # Parameters           #
#     ########################
#     image_h = 384
#     image_w = 512
#     ctx = [mx.gpu(0)] if mx.context.num_gpus() > 0 else [mx.cpu()]
#     print(ctx)
#     batch_size = args.batch_size
#     num_epochs = args.epochs
#     num_workers = 0 if num_epochs <= 2 else 6
#     learning_rate = args.lr
#     learning_rate_factor = args.lr_factor
#     class_factor = args.class_factor
#     wd = args.wd
#     model = args.model
#     classes = ["one", "two", "three", "four", "five", "six", "other"]
#     task = 'dice-labeling'
#
#     ########################
#     # Data                 #
#     ########################
#
#     train_dataset = GroundTruthDetectionDataset(split='train', data_path=args.train, task=task)
#     validation_dataset = GroundTruthDetectionDataset(split='val', data_path=args.train, task=task)
#
#     print("Example of bounding box label data [[x1,y1, x2, y2, class], ...] : {}".format(train_dataset[0][1]))
#     print("There is {} training images, {} validation images".format(len(train_dataset), len(validation_dataset)))
#
#     ########################
#     # Network              #
#     ########################
#     net = gcv.model_zoo.get_model(args.model, pretrained=True)
#     net.reset_class(classes)
#
#     train_data, val_data = get_dataloader(net, train_dataset, image_h, image_w, batch_size, num_workers)
#
#     net.collect_params().reset_ctx(ctx)
#     net.hybridize(static_alloc=True, static_shape=True)
#
#     ########################
#     # Optimizer            #
#     ########################
#     steps_epochs = [num_epochs / 3, (2*num_epochs)/3]
#     iterations_per_epoch = math.ceil(len(train_dataset) / batch_size)
#     steps_iterations = [int(s*iterations_per_epoch) for s in steps_epochs]
#     print("Learning rate drops after iterations: {}".format(steps_iterations))
#     schedule = mx.lr_scheduler.MultiFactorScheduler(step=steps_iterations, factor=learning_rate_factor)
#
#     trainer = gluon.Trainer(
#         net.collect_params(), 'adam',
#         {'learning_rate': learning_rate, 'wd': wd, 'lr_scheduler':schedule})
#
#     sigmoid_ce = gluon.loss.SigmoidBinaryCrossEntropyLoss(from_sigmoid=False)
#     l1_loss = gluon.loss.L1Loss()
#
#
#     best_mAP = 0
#     for epoch in range(num_epochs):
#         net.set_nms(nms_thresh=0.2, nms_topk=400, post_nms=100)
#         tic = time.time()
#         btic = time.time()
#         mx.nd.waitall()
#         obj_metrics = mx.metric.Loss('ObjLoss')
#         center_metrics = mx.metric.Loss('BoxCenterLoss')
#         scale_metrics = mx.metric.Loss('BoxScaleLoss')
#         cls_metrics = mx.metric.Loss('ClassLoss')
#         for i, batch in enumerate(train_data):
#             batch_size = batch[0].shape[0]
#             data = gluon.utils.split_and_load(batch[0], ctx_list=ctx, batch_axis=0)
#             # objectness, center_targets, scale_targets, weights, class_targets
#             fixed_targets = [gluon.utils.split_and_load(batch[it], ctx_list=ctx, batch_axis=0) for it in range(1, 6)]
#             gt_boxes = gluon.utils.split_and_load(batch[6], ctx_list=ctx, batch_axis=0)
#             sum_losses = []
#             obj_losses = []
#             center_losses = []
#             scale_losses = []
#             cls_losses = []
#             with autograd.record():
#                 for ix, x in enumerate(data):
#                     obj_loss, center_loss, scale_loss, cls_loss = net(x, gt_boxes[ix], *[ft[ix] for ft in fixed_targets])
#                     sum_losses.append(obj_loss + center_loss + scale_loss + cls_loss*class_factor)
#                     obj_losses.append(obj_loss)
#                     center_losses.append(center_loss)
#                     scale_losses.append(scale_loss)
#                     cls_losses.append(cls_loss*class_factor)
#                 autograd.backward(sum_losses)
#             trainer.step(batch_size)
#             obj_metrics.update(0, obj_losses)
#             center_metrics.update(0, center_losses)
#             scale_metrics.update(0, scale_losses)
#             cls_metrics.update(0, cls_losses)
#             btic = time.time()
#
#         name1, loss1 = obj_metrics.get()
#         name2, loss2 = center_metrics.get()
#         name3, loss3 = scale_metrics.get()
#         name4, loss4 = cls_metrics.get()
#         print('[Epoch {}] Training cost: {:.3f}, {}={:.3f}, {}={:.3f}, {}={:.3f}, {}={:.3f}'.format(
#             epoch, (time.time()-tic), name1, loss1, name2, loss2, name3, loss3, name4, loss4))
#         mAP = validate(net, val_data, ctx, net.classes)[1][-1]
#         if mAP > best_mAP:
#             print("Saving parameters")
#             net.export("{}/model".format(args.model_dir))
#             best_mAP = mAP
#
#         print("running mAP {}".format(mAP))
#
#     print("best mAP {}".format(best_mAP))
#
# # ------------------------------------------------------------ #
# # Hosting methods                                              #
# # ------------------------------------------------------------ #
#
#
# def model_fn(model_dir):
#     """
#     Load the gluon model. Called once when hosting service starts.
#     :param: model_dir The directory where model files are stored.
#     :return: a model (in this case a Gluon network)
#     """
#     net = gluon.SymbolBlock.imports(
#         '%s/model-symbol.json' % model_dir,
#         ['data'],
#         '%s/model-0000.params' % model_dir,
#     )
#     return net
#
#
# def transform_fn(net, data, input_content_type, output_content_type):
#     """
#     Transform a request using the Gluon model. Called once per request.
#     :param net: The Gluon model.
#     :param data: The request payload.
#     :param input_content_type: The request content type.
#     :param output_content_type: The (desired) response content type.
#     :return: response payload and content type.
#     """
#     # we can use content types to vary input/output handling, but
#     # here we just assume json for both
#     parsed = json.loads(data)
#     nda = np.array(parsed)
#     x, image = gcv.data.transforms.presets.yolo.transform_test(mx.nd.array(nda), 384)
#     cid, score, bbox = net(x)
#     response_body = json.dumps(
#         {"cid":cid.asnumpy().tolist()[0],
#          "score":score.asnumpy().tolist()[0],
#          "bbox": bbox.asnumpy().tolist()[0]
#         })
#     return response_body, output_content_type
#
#
# def neo_preprocess(payload, content_type):
#
#     parsed = json.loads(payload)
#     nda = np.array(parsed)
#
#     return nda
#
# def neo_postprocess(result):
#
#     response_body = json.dumps(result)
#     content_type = 'application/json'
#
#     return response_body, content_type

# %% [markdown]
# We obtain the default sagemaker bucket, and upload the training images and manifest to that bucket

# %%
sage_session = sagemaker.session.Session()
s3_bucket = sage_session.default_bucket()  
s3_output_path = 's3://{}/'.format(s3_bucket)
print("S3 bucket path: {}".format(s3_output_path))

# %% [markdown]
# ### Configuring the environment

# %% [markdown]
# 1) It is always a good practice to run first the training job in local model in order to make sure that the training complete successfully, this allows much faster feedback cycle than waiting for the creation of remote instances
#
# 2) After running in local_mode = True, try with local_mode = False and run the hyper-parameter tuning job!

# %%
# run in local_mode on this machine, or as a SageMaker TrainingJob?
local_mode = False

if local_mode:
    instance_type = 'local' if mx.context.num_gpus() == 0 else 'local_gpu'
else:
    # If on SageMaker, pick the instance type
    instance_type = "ml.p3.2xlarge"

# %%
try:
    role = sagemaker.get_execution_role()
except:
    role = get_execution_role()

print("Using IAM role arn: {}".format(role))

# %%
# only run from SageMaker notebook instance
if local_mode:
    # !/bin/bash ./setup.sh

# %% [markdown]
# ### Job definition

# %%
# create a descriptive job name 
job_name_prefix = 'hpo-dice-yolo'

# %% [markdown]
# Hyperparameters

# %%
static_hyperparameters = {
    'epochs': 2 if local_mode else 60
}

# %% [markdown]
# ### Estimator

# %%
from sagemaker.mxnet.estimator import MXNet
estimator = MXNet(entry_point="src/train_yolo.py",
                  role=role,
                  train_instance_type=instance_type,
                  train_instance_count=1,
                  output_path=s3_output_path,
                  framework_version="1.4.1",
                  py_version='py3',
                  base_job_name=job_name_prefix,
                  hyperparameters=static_hyperparameters
                 )

# %% [markdown]
# Let's first run in local mode, then we can go back and switch it to remote mode

# %%
if local_mode:
    estimator.fit({"train": training_images})

# %% [markdown]
# ### Hyperparameter Tuner job
#
# We are going to run an hyper-parameter tuning job, it is using gaussian processes to estimate the best combination of parameters. Try picking some ranges based on what you know of ML and let the system finds the best candidates for you

# %% [markdown]
# ### Metrics
# We define the metric that we are going to track, we want to track:
# - the current running validation Mean Average Precision: `run_validation_mAP`
# - the final best validation Mean Average Precision: `validation_mAP`

# %% [markdown]
# <img src="https://www.pyimagesearch.com/wp-content/uploads/2016/09/iou_equation.png"  width=400>

# %%
metric_definitions = [
    {'Name': 'validation_mAP', 'Regex': 'best mAP ([-+]?[0-9]*[.]?[0-9]+([eE][-+]?[0-9]+)?)'},
    {'Name': 'run_validation_mAP', 'Regex': 'running mAP ([-+]?[0-9]*[.]?[0-9]+([eE][-+]?[0-9]+)?)'}]

# %% [markdown]
# ### HPO job parameters

# %%
from sagemaker.tuner import IntegerParameter, CategoricalParameter, ContinuousParameter, HyperparameterTuner

# The hyperparameters we're going to tune
hyperparameter_ranges = {
    'lr': ContinuousParameter(0.0001, 0.005), # learning rate, how much should the model learn from the current iteration ( < 0.01 )
    'batch_size': IntegerParameter(1, 10), # batch size, how many pictures in each learning iteration (> 1)
    'lr_factor': ContinuousParameter(0.1, 1), # learning rate factor, How much to multiply the learning rate after 2/3 of trainign (0 < x < 1)
    'wd': ContinuousParameter(0.0000001, 0.0001), # Weight decay: Regularization to force small weights ( < 0.001 )
    'class_factor': ContinuousParameter(1, 30), # Class factor: How much to weigh the importance of getting the right class vs finding objects (> 1)
    'model': CategoricalParameter(["yolo3_darknet53_coco", "yolo3_mobilenet1.0_coco"]),
}

# %%
max_jobs = 4
max_parallel_jobs = 2

# %%
tuner = HyperparameterTuner(estimator,
                            objective_metric_name='validation_mAP',
                            objective_type='Maximize',
                            hyperparameter_ranges=hyperparameter_ranges,
                            metric_definitions=metric_definitions,
                            max_jobs=max_jobs,
                            max_parallel_jobs=max_parallel_jobs,
                            base_tuning_job_name=job_name_prefix
                           )
tuner.fit({"train":training_images})

# %%
job_name = tuner.latest_tuning_job.job_name
print("Tuning job: %s" % job_name)

# %% [markdown]
# You can monitor the progress of your jobs here: https://us-east-1.console.aws.amazon.com/sagemaker/home?region=us-east-1#/hyper-tuning-jobs

# %%
assert local_mode, "You need to go back up and modify local_mode to be False, and re-run all the cells until here"

# %% [markdown]
# <h1 style="color: red">Stop Here!</h1>
#
# Now go back up to <a href="#Fine-tuning-an-object-detection-model">here</a> and we'll set `local_mode=True` to show how to run it locally before using remote instances for training, you can also try a different hyper-parameter range.

# %%
best_job = tuner.best_training_job()
tuner.best_training_job()

# %% [markdown]
# ## Deployment

# %% [markdown]
# Deploy the best tuning job

# %%
estimator_best_job = estimator.attach(best_job, sage_session)

# %% [markdown]
# We deploy the best tuning job on a cluster of one CPU instance

# %%
deployed_model = estimator_best_job.deploy(1, 'ml.c5.4xlarge')

# %% [markdown]
# Predict bounding boxes

# %%
x, image = gcv.data.transforms.presets.yolo.load_test('test.jpg', short=384)
output = deployed_model.predict(image)

# %% [markdown]
# Visualize the result

# %%
cid = np.array(output['cid'])
scores = np.array(output['score'])
bbox = np.array(output['bbox'])


o = gcv.utils.viz.plot_bbox(image, bbox, scores, cid, class_names=classes)

# %% [markdown]
# ## Running inference with the webcam

# %% [markdown]
# We are going to process the images from the browser, to the endpoint and back
#
# This **ONLY** works in Jupyter Notebook **NOT** in Jupyter Labs
#
#
# 1) START: Capture an image in javascript through the webcam in the browse
#
# 2) Convert that image to base64 and send it over to the python kernel
#
# 3) Convert the image back to numpy and send it over to the SageMaker endpoint
#
# 4) Get the predicted bounding boxes and paint them over the numpy image
#
# 5) Convert the annoted image back to base64 and send it to the javascript
#
# 6) Display the annoted frame
#
# 7) GOTO START

# %%
import base64
from io import BytesIO
from PIL import Image
from utils import show_webcam
def get_annotated_image(input_image_b64):
    prefix, input_image_b64 = input_image_b64.split(',')
    input_image_binary = BytesIO(base64.b64decode(input_image_b64))
    input_image_np = np.asarray(Image.open(input_image_binary))
    input_image_np, _ = mx.image.center_crop(mx.nd.array(input_image_np), (512,384))
    _, input_image_loaded = gcv.data.transforms.presets.yolo.transform_test(input_image_np, short=384)
    output = deployed_model.predict(input_image_loaded)
    cid = np.array(output['cid'])
    scores = np.array(output['score'])
    bbox = np.array(output['bbox'])
    output_image_np = gcv.utils.viz.cv_plot_bbox(input_image_loaded, bbox, scores, cid, class_names=classes)
    output_image_PIL = Image.fromarray(output_image_np)
    output_buffer = BytesIO()
    output_image_PIL.save(output_buffer, format="JPEG")
    output_image_b64 = 'data:image/jpeg;base64,'+base64.b64encode(output_buffer.getvalue()).decode("utf-8")
    print(output_image_b64)

#show_webcam()
display()

# %% [markdown]
# ## Compilation

# %% [markdown]
# We can compile the model for faster runtime on specific platforms, in the cloud or on the edge

# %%
compiled_model = estimator_best_job.compile_model('ml_c5', {'data' : (1, 3, 384, 512)}, s3_output_path, framework='mxnet', framework_version='1.4.1')

# %%
# %matplotlib inline
import os
from collections import namedtuple
from collections import defaultdict
from collections import Counter
from datetime import datetime
import itertools
import base64
import glob
import json
import random
import time
import imageio
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import shutil
from matplotlib.backends.backend_pdf import PdfPages
from sklearn.metrics import confusion_matrix
import boto3
import botocore
import sagemaker
from urllib.parse import urlparse

BUCKET = 'bcbs-logos'

# %%
# Load the output manifest's annotations.
OUTPUT_MANIFEST = 's3://bcbs-logos/label/bcbs-logos/manifests/output/output.manifest'

# !aws s3 cp {OUTPUT_MANIFEST} 'output.manifest'

with open('output.manifest', 'r') as f:
    output = [json.loads(line.strip()) for line in f.readlines()]

           
# Retrieve the worker annotations.
# !aws s3 cp {'s3://bcbs-logos/label/bcbs-logos//annotations/worker-response'} od_output_data/worker-response --recursive --quiet

# Find the worker files.
worker_file_names = glob.glob(
    'od_output_data/worker-response/**/*.json', recursive=True)
# Out:
# download: s3://bcbs-logos/label/bcbs-logos/manifests/output/output.manifest to ./output.manifest

# %%
from ground_truth_od import BoundingBox, WorkerBoundingBox, \
    GroundTruthBox, BoxedImage

# Create data arrays.
confidences = np.zeros(len(output))

# Find the job name the manifest corresponds to.
keys = list(output[0].keys())
metakey = keys[np.where([('-metadata' in k) for k in keys])[0][0]]
jobname = metakey[:-9]
output_images = []
consolidated_boxes = []

# Extract the data.
for datum_id, datum in enumerate(output):
    image_size = datum['category']['image_size'][0]
    box_annotations = datum['category']['annotations']
    uri = datum['source-ref']
    box_confidences = datum[metakey]['objects']
    human = int(datum[metakey]['human-annotated'] == 'yes')

    # Make image object.
    image = BoxedImage(id=datum_id, size=image_size,
                       uri=uri)

    # Create bounding boxes for image.
    boxes = []
    for i, annotation in enumerate(box_annotations):
        box = BoundingBox(image_id=datum_id, boxdata=annotation)
        box.confidence = box_confidences[i]['confidence']
        box.image = image
        box.human = human
        boxes.append(box)
        consolidated_boxes.append(box)
    image.consolidated_boxes = boxes

    # Store if the image is human labeled.
    image.human = human

    # Retrieve ground truth boxes for the image.
    oid_boxes_data = fids2bbs[image.oid_id]
    gt_boxes = []
    for data in oid_boxes_data:
        gt_box = GroundTruthBox(image_id=datum_id, oiddata=data,
                                image=image)
        gt_boxes.append(gt_box)
    image.gt_boxes = gt_boxes

    output_images.append(image)

# Iterate through the json files, creating bounding box objects.
for wfn in worker_file_names:
    image_id = int(wfn.split('/')[-2])
    image = output_images[image_id]
    with open(wfn, "r") as worker_file:
        annotation = json.load(worker_file)
        answers = annotation['answers']
        for answer in answers:
            wid = answer['workerId']
            wboxes_data = \
                answer['answerContent']['boundingBox']['boundingBoxes']
            for boxdata in (wboxes_data or []):
                box = WorkerBoundingBox(image_id=image_id,
                                        worker_id=wid,
                                        boxdata=boxdata)
                box.image = image
                image.worker_boxes.append(box)

# Get the human- and auto-labeled images.
human_labeled = [img for img in output_images if img.human]
auto_labeled = [img for img in output_images if not img.human]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-3-6c378db665a6> in <module>()
#      13 # Extract the data.
#      14 for datum_id, datum in enumerate(output):
# ---> 15     image_size = datum['category']['image_size'][0]
#      16     box_annotations = datum['category']['annotations']
#      17     uri = datum['source-ref']
#
# KeyError: 'category'
